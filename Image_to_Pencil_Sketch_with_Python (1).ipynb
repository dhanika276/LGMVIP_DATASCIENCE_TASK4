# %% [markdown]
# Lets Grow More VIP

# %% [markdown]
# Data Science Internship

# %% [markdown]
# Name:-Hegde Dhanika Dhananjaya

# %% [markdown]
# Beginner level Task 4:- Image to Pencil Sketch with Python

# %% [markdown]
# To programmatically transform a color image into a black and white pencil sketch with enhanced details, we first read the image in RGB format. Convert the image to grayscale, removing color information. Then create an inverted grayscale image by reversing the intensity values.Blend the grayscale and inverted blurry images by dividing corresponding pixel values. The resulting image will resemble a pencil sketch.

# %% [markdown]
# Importing Libraries

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# Now lets read the image

# %%
image=cv2.imread("/content/website.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x510>

# %% [markdown]
# So we will convert the Original image to Gray scale image

# %%
gray_scale_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=1020x510>

# %% [markdown]
# # New Section

# %% [markdown]
# Inverting the gray scale image

# %%
inverted_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=1020x510>

# %% [markdown]
# The gaussian blur technique and the default sigma values filter on the image to smoothen our image.

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=1020x510>

# %%
def pencil_sketch(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %% [markdown]
# The final stage where we will be making the final pencil sketch

# %%
pencil_sketch=pencil_sketch(gray_scale_image,img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1020x510>

# %% [markdown]
# This is Original image and Pencil sketch

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x510>
# <PIL.Image.Image image mode=L size=1020x510>
